# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib3
from pprint import pprint
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f'Number of cities in the list: {len(cities)}')
# Out:
# Number of cities in the list: 589

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
# 'https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}'
url = 'https://api.openweathermap.org/data/2.5/weather?q='
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print('Beginning Data Retrieval     ')
print('-----------------------------')

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    units = 'metric'
    city_url = f'{url}{city}&appid={weather_api_key}&units={units}'

    # Confirm request went through
    try:
        weather_response = requests.get(city_url)
        weather_response.raise_for_status()
    except:
        print(f'{city.title()} not found. Skipping...')
        continue
        
    # Log the url, record, and set numbers
    print('Processing Record %s of Set %s | %s' % (record_count, set_count, city.title()))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = weather_response.json()
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({'City': city,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Country': city_country,
                          'Date': city_date})

    # If an error is experienced, skip the city
    except:
        print(f'{city.title()} not found. Skipping...')
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print('-----------------------------')
print('Data Retrieval Complete      ')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Nuuk
# Processing Record 2 of Set 1 | Isafjordur
# Processing Record 3 of Set 1 | East London
# Processing Record 4 of Set 1 | Bredasdorp
# Processing Record 5 of Set 1 | Adamstown
# Processing Record 6 of Set 1 | Kingston
# Processing Record 7 of Set 1 | Nemuro
# Processing Record 8 of Set 1 | Susuman
# Processing Record 9 of Set 1 | Mata-Utu
# Processing Record 10 of Set 1 | Harstad
# Processing Record 11 of Set 1 | Sainte-Rose
# Processing Record 12 of Set 1 | Olonkinbyen
# Processing Record 13 of Set 1 | Georgetown
# Processing Record 14 of Set 1 | Grytviken
# Processing Record 15 of Set 1 | Lerwick
# Processing Record 16 of Set 1 | Yellowknife
# Processing Record 17 of Set 1 | Rongelap
# Processing Record 18 of Set 1 | Iqaluit
# Processing Record 19 of Set 1 | Hadibu
# Processing Record 20 of Set 1 | Huarmey
# Processing Record 21 of Set 1 | Stanley
# Processing Record 22 of Set 1 | Qaqortoq
# Processing Record 23 of Set 1 | Bondo
# Processing Record 24 of Set 1 | Klyuchi
# Processing Record 25 of Set 1 | Hermanus
# Processing Record 26 of Set 1 | Waitangi
# Processing Record 27 of Set 1 | Port Mathurin
# Processing Record 28 of Set 1 | Udachny
# Processing Record 29 of Set 1 | Happy Valley-Goose Bay
# Processing Record 30 of Set 1 | Coruripe
# Processing Record 31 of Set 1 | Port Alberni
# Puerto San Carlos not found. Skipping...
# Processing Record 32 of Set 1 | New Norfolk
# Processing Record 33 of Set 1 | Touros
# Processing Record 34 of Set 1 | West Island
# Processing Record 35 of Set 1 | Okha
# Sishilichengzi not found. Skipping...
# Processing Record 36 of Set 1 | Puerto Natales
# Processing Record 37 of Set 1 | Tiksi
# Processing Record 38 of Set 1 | Nar'Yan-Mar
# Processing Record 39 of Set 1 | Dali
# Processing Record 40 of Set 1 | Tazacorte
# Processing Record 41 of Set 1 | Ingeniero Guillermo N. Juarez
# Processing Record 42 of Set 1 | Turkmenbasy
# Processing Record 43 of Set 1 | Saipan
# Processing Record 44 of Set 1 | Aykhal
# Processing Record 45 of Set 1 | Bardstown
# Processing Record 46 of Set 1 | Edinburgh Of The Seven Seas
# Processing Record 47 of Set 1 | Kalmunai
# Processing Record 48 of Set 1 | La'Ie
# Processing Record 0 of Set 2 | Leninskoye
# Processing Record 1 of Set 2 | Port-Aux-Francais
# Processing Record 2 of Set 2 | Juuka
# Processing Record 3 of Set 2 | Strathalbyn
# Processing Record 4 of Set 2 | Silapathar
# San Antonio Del Estrecho not found. Skipping...
# Processing Record 5 of Set 2 | Kodiak
# Processing Record 6 of Set 2 | Tadine
# Processing Record 7 of Set 2 | Bethel
# Processing Record 8 of Set 2 | Iskateley
# Processing Record 9 of Set 2 | Hirara
# Processing Record 10 of Set 2 | Blackmans Bay
# Processing Record 11 of Set 2 | Mount Gambier
# Processing Record 12 of Set 2 | Nanao
# Processing Record 13 of Set 2 | Talas
# Processing Record 14 of Set 2 | Flying Fish Cove
# Processing Record 15 of Set 2 | Zephyrhills South
# Processing Record 16 of Set 2 | Hawaiian Paradise Park
# Processing Record 17 of Set 2 | Fairbanks
# Processing Record 18 of Set 2 | Callao
# Processing Record 19 of Set 2 | Paka
# Processing Record 20 of Set 2 | Zhirnovsk
# Processing Record 21 of Set 2 | Zhangye
# Processing Record 22 of Set 2 | Loikaw
# Processing Record 23 of Set 2 | Invercargill
# Processing Record 24 of Set 2 | Ribeira Grande
# Processing Record 25 of Set 2 | Remire-Montjoly
# Processing Record 26 of Set 2 | Anna Regina
# Processing Record 27 of Set 2 | Kapuskasing
# Processing Record 28 of Set 2 | Grand Falls-Windsor
# Processing Record 29 of Set 2 | Khorixas
# Processing Record 30 of Set 2 | Arkalyk
# Processing Record 31 of Set 2 | Sosnovo-Ozerskoye
# Processing Record 32 of Set 2 | Wailua Homesteads
# Processing Record 33 of Set 2 | Ketchikan
# Processing Record 34 of Set 2 | Codrington
# Processing Record 35 of Set 2 | Lihue
# Processing Record 36 of Set 2 | Lompoc
# Processing Record 37 of Set 2 | Colonia Menno
# Processing Record 38 of Set 2 | Villa Berthet
# Processing Record 39 of Set 2 | Whitehorse
# Processing Record 40 of Set 2 | Afaahiti
# Processing Record 41 of Set 2 | Punta Arenas
# Processing Record 42 of Set 2 | Betio Village
# Processing Record 43 of Set 2 | Tianpeng
# Processing Record 44 of Set 2 | Longyearbyen
# Processing Record 45 of Set 2 | Sao Raimundo Das Mangabeiras
# Processing Record 46 of Set 2 | Brinkmann
# Processing Record 47 of Set 2 | Tazovsky
# Processing Record 48 of Set 2 | Lebedyn
# Processing Record 0 of Set 3 | Sao Geraldo Do Araguaia
# Antsohimbondrona not found. Skipping...
# Processing Record 1 of Set 3 | Undurkhaan
# Processing Record 2 of Set 3 | Zabol
# Processing Record 3 of Set 3 | Bilisht
# Processing Record 4 of Set 3 | Avarua
# Processing Record 5 of Set 3 | Atafu Village
# Processing Record 6 of Set 3 | Tepatitlan De Morelos
# Processing Record 7 of Set 3 | Labytnangi
# Processing Record 8 of Set 3 | Jamestown
# Processing Record 9 of Set 3 | Port Lincoln
# Taiohae not found. Skipping...
# Processing Record 10 of Set 3 | Geraldton
# Processing Record 11 of Set 3 | Sitia
# Processing Record 12 of Set 3 | Aioun
# Processing Record 13 of Set 3 | Naze
# Processing Record 14 of Set 3 | Alofi
# 'Ohonua not found. Skipping...
# Casa Santa not found. Skipping...
# Processing Record 15 of Set 3 | Garissa
# Processing Record 16 of Set 3 | Ushuaia
# Processing Record 17 of Set 3 | Ilulissat
# Processing Record 18 of Set 3 | Lorengau
# Processing Record 19 of Set 3 | Vilyuysk
# Processing Record 20 of Set 3 | Holualoa
# Processing Record 21 of Set 3 | Peace River
# Processing Record 22 of Set 3 | Kirovo-Chepetsk
# Processing Record 23 of Set 3 | Tomatlan
# Processing Record 24 of Set 3 | Punxsutawney
# Processing Record 25 of Set 3 | Arraial Do Cabo
# Processing Record 26 of Set 3 | Vadso
# Processing Record 27 of Set 3 | Trashi Yangtse
# Processing Record 28 of Set 3 | Kostomuksha
# Processing Record 29 of Set 3 | Makinsk
# Processing Record 30 of Set 3 | Meadow Lake
# Processing Record 31 of Set 3 | Coahuayana De Hidalgo
# Processing Record 32 of Set 3 | Bengkulu
# Processing Record 33 of Set 3 | San Antonio De Pale
# Processing Record 34 of Set 3 | Antalaha
# Processing Record 35 of Set 3 | College
# Processing Record 36 of Set 3 | Colonia
# Processing Record 37 of Set 3 | Tralee
# Processing Record 38 of Set 3 | El Granada
# Processing Record 39 of Set 3 | Basco
# Processing Record 40 of Set 3 | Tual
# Processing Record 41 of Set 3 | Filadelfia
# Processing Record 42 of Set 3 | Sidi Bouzid
# Processing Record 43 of Set 3 | Yeppoon
# Processing Record 44 of Set 3 | Vila Do Maio
# Processing Record 45 of Set 3 | Berezovyy
# Processing Record 0 of Set 4 | Terbanggi Besar
# Processing Record 1 of Set 4 | Al Ghayzah
# Processing Record 2 of Set 4 | Puerto Real
# Processing Record 3 of Set 4 | Camabatela
# Processing Record 4 of Set 4 | Ebon
# Processing Record 5 of Set 4 | Horta
# Processing Record 6 of Set 4 | Hami
# Processing Record 7 of Set 4 | Broome
# Processing Record 8 of Set 4 | Ancud
# Processing Record 9 of Set 4 | Luderitz
# Processing Record 10 of Set 4 | Petropavlovsk-Kamchatsky
# Processing Record 11 of Set 4 | Bodo
# Processing Record 12 of Set 4 | Carnarvon
# Processing Record 13 of Set 4 | China
# Processing Record 14 of Set 4 | Usinsk
# Processing Record 15 of Set 4 | Laojunmiao
# Processing Record 16 of Set 4 | Queenstown
# Processing Record 17 of Set 4 | Albany
# Processing Record 18 of Set 4 | Minas De Marcona
# Processing Record 19 of Set 4 | Saldanha
# Processing Record 20 of Set 4 | Calama
# Processing Record 21 of Set 4 | Angaur State
# Processing Record 22 of Set 4 | Endicott
# Processing Record 23 of Set 4 | Sur
# Processing Record 24 of Set 4 | Xinqing
# Processing Record 25 of Set 4 | Castillos
# Processing Record 26 of Set 4 | Lethem
# Processing Record 27 of Set 4 | Arteche
# Processing Record 28 of Set 4 | Brookings
# Processing Record 29 of Set 4 | Namibe
# Processing Record 30 of Set 4 | Thompson
# Processing Record 31 of Set 4 | Keflavik
# Processing Record 32 of Set 4 | Pangai
# Processing Record 33 of Set 4 | Aguadilla
# Processing Record 34 of Set 4 | Mancio Lima
# Toga Village not found. Skipping...
# Processing Record 35 of Set 4 | Ciudad Del Carmen
# Processing Record 36 of Set 4 | Vallenar
# Processing Record 37 of Set 4 | Port Elizabeth
# Processing Record 38 of Set 4 | Constantia
# West End Village not found. Skipping...
# Processing Record 39 of Set 4 | Guacimo
# Processing Record 40 of Set 4 | Mezhdurechenskiy
# Processing Record 41 of Set 4 | Papatowai
# Processing Record 42 of Set 4 | Brush
# Processing Record 43 of Set 4 | Nhamunda
# Processing Record 44 of Set 4 | Trinity Beach
# Processing Record 45 of Set 4 | Lebu
# Processing Record 46 of Set 4 | Yuzhno-Kurilsk
# Processing Record 47 of Set 4 | Juegang
# Processing Record 0 of Set 5 | Toba
# Processing Record 1 of Set 5 | Haiku-Pauwela
# Processing Record 2 of Set 5 | Labrador City
# Processing Record 3 of Set 5 | Egilsstadir
# Processing Record 4 of Set 5 | Puerto Ayora
# Processing Record 5 of Set 5 | Puerto Colombia
# Processing Record 6 of Set 5 | Boa Vista
# Processing Record 7 of Set 5 | Anadyr
# Processing Record 8 of Set 5 | Buenaventura
# Processing Record 9 of Set 5 | Ingeniero Jacobacci
# Processing Record 10 of Set 5 | Sao Desiderio
# Processing Record 11 of Set 5 | Brades
# Processing Record 12 of Set 5 | Conde
# Processing Record 13 of Set 5 | Vila Velha
# Processing Record 14 of Set 5 | Pangody
# Processing Record 15 of Set 5 | Mundri
# Processing Record 16 of Set 5 | Alvaraes
# Processing Record 17 of Set 5 | Santa Terezinha
# Processing Record 18 of Set 5 | Thunder Bay
# Processing Record 19 of Set 5 | Ath Thawrah
# Processing Record 20 of Set 5 | Kete Krachi
# Processing Record 21 of Set 5 | La Sarre
# Processing Record 22 of Set 5 | Sinop
# Processing Record 23 of Set 5 | Mount Isa
# Processing Record 24 of Set 5 | Nizhniy Ingash
# Processing Record 25 of Set 5 | Gokak
# Processing Record 26 of Set 5 | Talnakh
# Processing Record 27 of Set 5 | Ad Dabbah
# Processing Record 28 of Set 5 | Greenville
# Processing Record 29 of Set 5 | Balkanabat
# Whyalla Stuart not found. Skipping...
# Processing Record 30 of Set 5 | Margaret River
# Processing Record 31 of Set 5 | Kerema
# Processing Record 32 of Set 5 | Kavieng
# Processing Record 33 of Set 5 | Mollendo
# Processing Record 34 of Set 5 | Sinabang
# Processing Record 35 of Set 5 | Ust-Nera
# Processing Record 36 of Set 5 | Mejit
# Processing Record 37 of Set 5 | Kasungu
# Processing Record 38 of Set 5 | Alo
# Processing Record 39 of Set 5 | Floresville
# Processing Record 40 of Set 5 | Millau
# Processing Record 41 of Set 5 | Skelleftea
# Processing Record 42 of Set 5 | Red Wing
# Processing Record 43 of Set 5 | La Curva
# Processing Record 44 of Set 5 | Berdigestyakh
# Processing Record 45 of Set 5 | Sitka
# Processing Record 46 of Set 5 | Mugia
# Processing Record 47 of Set 5 | La Passe
# Processing Record 48 of Set 5 | Kourou
# Processing Record 0 of Set 6 | Guercif
# Processing Record 1 of Set 6 | Vilyuchinsk
# Processing Record 2 of Set 6 | Stratham Station
# Processing Record 3 of Set 6 | Weno
# Processing Record 4 of Set 6 | Puerto Aysen
# Processing Record 5 of Set 6 | Kincardine
# Processing Record 6 of Set 6 | Alzamay
# Processing Record 7 of Set 6 | San Luis De La Loma
# Processing Record 8 of Set 6 | Kachkanar
# Processing Record 9 of Set 6 | Pyin Oo Lwin
# Processing Record 10 of Set 6 | Tolanaro
# Processing Record 11 of Set 6 | Katabu
# Processing Record 12 of Set 6 | Port Blair
# Isle Of Lewis not found. Skipping...
# Processing Record 13 of Set 6 | Papao
# Processing Record 14 of Set 6 | Cuiaba
# Processing Record 15 of Set 6 | Port Alfred
# Processing Record 16 of Set 6 | Cidreira
# Processing Record 17 of Set 6 | Enewetak
# Processing Record 18 of Set 6 | Yoro
# Processing Record 19 of Set 6 | Imbituba
# Processing Record 20 of Set 6 | Kiunga
# Processing Record 21 of Set 6 | Uturoa
# Ourilandia Do Norte not found. Skipping...
# Processing Record 22 of Set 6 | Hamilton
# Processing Record 23 of Set 6 | Kayangel
# Processing Record 24 of Set 6 | Yallahs
# Processing Record 25 of Set 6 | Gizo
# Processing Record 26 of Set 6 | Ngorongoro
# Processing Record 27 of Set 6 | Paradip Garh
# Processing Record 28 of Set 6 | Dalbandin
# Processing Record 29 of Set 6 | Lycksele
# Processing Record 30 of Set 6 | San Jeronimo De Juarez
# Processing Record 31 of Set 6 | Amungan
# Processing Record 32 of Set 6 | Porto Novo
# Processing Record 33 of Set 6 | Sarkand
# Processing Record 34 of Set 6 | Nadi
# Processing Record 35 of Set 6 | Badger
# Processing Record 36 of Set 6 | Golfito
# Processing Record 37 of Set 6 | Shindand
# Processing Record 38 of Set 6 | Paracuru
# Processing Record 39 of Set 6 | Luena
# Processing Record 40 of Set 6 | Shar
# Processing Record 41 of Set 6 | Almodovar
# Processing Record 42 of Set 6 | Praia Da Vitoria
# Processing Record 43 of Set 6 | Ghadamis
# Processing Record 44 of Set 6 | Sainyabuli
# Processing Record 45 of Set 6 | Guaruja
# Processing Record 46 of Set 6 | Illizi
# Processing Record 47 of Set 6 | Cill Airne
# Processing Record 0 of Set 7 | Sayansk
# Processing Record 1 of Set 7 | Malango
# Processing Record 2 of Set 7 | Covington
# Processing Record 3 of Set 7 | Barakani
# Processing Record 4 of Set 7 | Oruro
# Processing Record 5 of Set 7 | Selfoss
# Processing Record 6 of Set 7 | Tsiombe
# Processing Record 7 of Set 7 | Utrik
# Processing Record 8 of Set 7 | Kerikeri
# Processing Record 9 of Set 7 | Nyaunglebin
# Processing Record 10 of Set 7 | Zurrieq
# Processing Record 11 of Set 7 | Lucas
# Processing Record 12 of Set 7 | Phang Nga
# Processing Record 13 of Set 7 | Daru
# Processing Record 14 of Set 7 | Reftinskiy
# Processing Record 15 of Set 7 | Trairi
# Processing Record 16 of Set 7 | Brisas De Zicatela
# Processing Record 17 of Set 7 | Calvinia
# Processing Record 18 of Set 7 | Kirov
# Processing Record 19 of Set 7 | Sultanah
# Processing Record 20 of Set 7 | Hammerfest
# Processing Record 21 of Set 7 | Salavan
# Processing Record 22 of Set 7 | Phalodi
# Processing Record 23 of Set 7 | Chinchilla
# Processing Record 24 of Set 7 | Howrah
# Processing Record 25 of Set 7 | Doka
# Processing Record 26 of Set 7 | Pisco
# Processing Record 27 of Set 7 | Pioner
# Processing Record 28 of Set 7 | Sisimiut
# Processing Record 29 of Set 7 | Santa Ana
# Processing Record 30 of Set 7 | Bilibino
# Processing Record 31 of Set 7 | Nouadhibou
# Processing Record 32 of Set 7 | Abepura
# Processing Record 33 of Set 7 | Sault Ste. Marie
# Processing Record 34 of Set 7 | Vershino-Darasunskiy
# Processing Record 35 of Set 7 | Touggourt
# Processing Record 36 of Set 7 | Kismayo
# Processing Record 37 of Set 7 | Ola
# Processing Record 38 of Set 7 | Salinopolis
# Processing Record 39 of Set 7 | Gorokhovets
# Processing Record 40 of Set 7 | Elliot Lake
# Processing Record 41 of Set 7 | Borgarnes
# Processing Record 42 of Set 7 | Vorgashor
# Processing Record 43 of Set 7 | Hasaki
# Processing Record 44 of Set 7 | Sredniy
# Processing Record 45 of Set 7 | Taixing
# Processing Record 46 of Set 7 | Lata
# Processing Record 47 of Set 7 | Wotho
# Processing Record 48 of Set 7 | Independence
# Processing Record 49 of Set 7 | Iuna
# Processing Record 0 of Set 8 | Nogliki
# Processing Record 1 of Set 8 | Birao
# Processing Record 2 of Set 8 | St. John'S
# Processing Record 3 of Set 8 | Pochinki
# Processing Record 4 of Set 8 | Santiago De Cao
# Processing Record 5 of Set 8 | Al Kharijah
# Processing Record 6 of Set 8 | Lesnoy
# Processing Record 7 of Set 8 | Tromso
# Processing Record 8 of Set 8 | Shevchenko
# Processing Record 9 of Set 8 | Buala
# Processing Record 10 of Set 8 | Iquique
# Processing Record 11 of Set 8 | Cadale
# Processing Record 12 of Set 8 | San Patricio
# Processing Record 13 of Set 8 | Kununurra
# Processing Record 14 of Set 8 | Suchindram
# Processing Record 15 of Set 8 | Gaiman
# Processing Record 16 of Set 8 | Palikir - National Government Center
# Processing Record 17 of Set 8 | Zheleznodorozhnyy
# Processing Record 18 of Set 8 | Kyshtovka
# Processing Record 19 of Set 8 | Ratzeburg
# Processing Record 20 of Set 8 | Stornoway
# Processing Record 21 of Set 8 | Waingapu
# Processing Record 22 of Set 8 | Fortuna
# Processing Record 23 of Set 8 | Tvoroyri
# Processing Record 24 of Set 8 | Chulym
# Processing Record 25 of Set 8 | Maceio
# Processing Record 26 of Set 8 | Ihosy
# Processing Record 27 of Set 8 | Kalabo
# Processing Record 28 of Set 8 | Kabompo
# Processing Record 29 of Set 8 | Nelson Bay
# Processing Record 30 of Set 8 | Pandan
# Processing Record 31 of Set 8 | Diego De Almagro
# Processing Record 32 of Set 8 | Usogorsk
# Processing Record 33 of Set 8 | Chonchi
# Processing Record 34 of Set 8 | Tocopilla
# Processing Record 35 of Set 8 | Portland
# Processing Record 36 of Set 8 | Gogrial
# Processing Record 37 of Set 8 | Buka
# Processing Record 38 of Set 8 | Kijang
# Processing Record 39 of Set 8 | Qurayyat
# Processing Record 40 of Set 8 | Ndjole
# Processing Record 41 of Set 8 | Newman
# Processing Record 42 of Set 8 | Susanville
# Processing Record 43 of Set 8 | Gazli
# Processing Record 44 of Set 8 | Aransas Pass
# Processing Record 45 of Set 8 | Gadzhiyevo
# Processing Record 46 of Set 8 | Celestun
# Processing Record 47 of Set 8 | Buritizeiro
# Processing Record 48 of Set 8 | Palafrugell
# Processing Record 49 of Set 8 | Ar Rutbah
# Processing Record 0 of Set 9 | Cheremkhovo
# Processing Record 1 of Set 9 | Puerto Baquerizo Moreno
# Processing Record 2 of Set 9 | Fort St. John
# Processing Record 3 of Set 9 | Safi
# Processing Record 4 of Set 9 | Hilo
# Processing Record 5 of Set 9 | Nova Sintra
# Processing Record 6 of Set 9 | Cabo San Lucas
# Processing Record 7 of Set 9 | Ciudad Acuna
# Processing Record 8 of Set 9 | Imuris
# Cable Beach not found. Skipping...
# Processing Record 9 of Set 9 | Khovd
# Processing Record 10 of Set 9 | Tarauaca
# Processing Record 11 of Set 9 | Fale Old Settlement
# Mayen Abun not found. Skipping...
# Processing Record 12 of Set 9 | Carbonear
# Processing Record 13 of Set 9 | Calatagan
# Processing Record 14 of Set 9 | Lamu
# Processing Record 15 of Set 9 | Woolgoolga
# Processing Record 16 of Set 9 | Gryfice
# Processing Record 17 of Set 9 | Suoyarvi
# Processing Record 18 of Set 9 | San Matias
# Processing Record 19 of Set 9 | Puro
# Processing Record 20 of Set 9 | Cabinda
# Processing Record 21 of Set 9 | Miyaly
# Processing Record 22 of Set 9 | Tura
# Processing Record 23 of Set 9 | Al Hufuf
# Processing Record 24 of Set 9 | Chokwe
# Processing Record 25 of Set 9 | Catriel
# Processing Record 26 of Set 9 | Vilhena
# Processing Record 27 of Set 9 | Sogod
# Processing Record 28 of Set 9 | Greenland
# Processing Record 29 of Set 9 | Tommot
# Processing Record 30 of Set 9 | Baikonur
# Processing Record 31 of Set 9 | Robertson
# Processing Record 32 of Set 9 | Mercedes
# Processing Record 33 of Set 9 | Baruun-Urt
# Processing Record 34 of Set 9 | Darwin
# Processing Record 35 of Set 9 | Fort Bragg
# Processing Record 36 of Set 9 | Oeiras Do Para
# Processing Record 37 of Set 9 | Mitu
# Processing Record 38 of Set 9 | Livingston
# Processing Record 39 of Set 9 | Inhambane
# Processing Record 40 of Set 9 | Khilok
# Processing Record 41 of Set 9 | Boysun
# Processing Record 42 of Set 9 | Aixe-Sur-Vienne
# Processing Record 43 of Set 9 | Duyun
# Processing Record 44 of Set 9 | Nalut
# Processing Record 45 of Set 9 | San Lorenzo Cacaotepec
# Processing Record 46 of Set 9 | Turpan
# Processing Record 47 of Set 9 | La Ronge
# Processing Record 0 of Set 10 | Hola
# Processing Record 1 of Set 10 | Angra Do Heroismo
# Processing Record 2 of Set 10 | Korsholm
# Processing Record 3 of Set 10 | Alcudia
# Processing Record 4 of Set 10 | Kyren
# Processing Record 5 of Set 10 | Bakchar
# Processing Record 6 of Set 10 | Pemangkat
# Processing Record 7 of Set 10 | Ryotsu-Minato
# Processing Record 8 of Set 10 | I-N-Salah
# Processing Record 9 of Set 10 | Kotzting
# Processing Record 10 of Set 10 | Yevpatoriya
# Processing Record 11 of Set 10 | Rio Tuba
# Processing Record 12 of Set 10 | Bairnsdale
# Processing Record 13 of Set 10 | Kotlas
# Processing Record 14 of Set 10 | Verkhnevilyuysk
# Processing Record 15 of Set 10 | Umarizal
# Processing Record 16 of Set 10 | Inirida
# Processing Record 17 of Set 10 | Smithers
# Processing Record 18 of Set 10 | Kuruman
# Processing Record 19 of Set 10 | Bonthe
# Processing Record 20 of Set 10 | Azemmour
# Processing Record 21 of Set 10 | Dudinka
# Processing Record 22 of Set 10 | Bonny
# Processing Record 23 of Set 10 | Tirmiz
# Processing Record 24 of Set 10 | Tweed Heads
# Processing Record 25 of Set 10 | Amahai
# Processing Record 26 of Set 10 | Melfort
# Processing Record 27 of Set 10 | Mamuju
# Processing Record 28 of Set 10 | Marrakesh
# Processing Record 29 of Set 10 | Ust'-Ilimsk
# Processing Record 30 of Set 10 | Chibougamau
# Processing Record 31 of Set 10 | Kilmore
# Processing Record 32 of Set 10 | Cuamba
# Processing Record 33 of Set 10 | Puerto Rico
# Processing Record 34 of Set 10 | Steinau An Der Strasse
# Kocahasanli not found. Skipping...
# Processing Record 35 of Set 10 | Mahina
# Processing Record 36 of Set 10 | Cruz Del Eje
# Processing Record 37 of Set 10 | Rockingham
# Nkurenkuru not found. Skipping...
# Processing Record 38 of Set 10 | Bardai
# Processing Record 39 of Set 10 | Itamaraju
# Processing Record 40 of Set 10 | Cuttack
# Processing Record 41 of Set 10 | La Rioja
# Processing Record 42 of Set 10 | Banda Aceh
# Processing Record 43 of Set 10 | Saint-Pierre
# Processing Record 44 of Set 10 | Fort-Shevchenko
# Processing Record 45 of Set 10 | Malpe
# Processing Record 46 of Set 10 | Tekkali
# Processing Record 47 of Set 10 | Cradock
# Processing Record 0 of Set 11 | Xiva
# Processing Record 1 of Set 11 | Coquimbo
# Processing Record 2 of Set 11 | East Stroudsburg
# Processing Record 3 of Set 11 | Ovalle
# Fuvahmulah not found. Skipping...
# Processing Record 4 of Set 11 | Buerarema
# Processing Record 5 of Set 11 | Collie
# Processing Record 6 of Set 11 | Anzio
# Processing Record 7 of Set 11 | Lashio
# Processing Record 8 of Set 11 | Guatrache
# Processing Record 9 of Set 11 | Salamanca
# Processing Record 10 of Set 11 | Dahab
# Processing Record 11 of Set 11 | Prince Rupert
# Processing Record 12 of Set 11 | Kuanda
# Processing Record 13 of Set 11 | Bestobe
# Processing Record 14 of Set 11 | El Calafate
# Processing Record 15 of Set 11 | Kenora
# Processing Record 16 of Set 11 | Rafsanjan
# Tanrake Village not found. Skipping...
# Processing Record 17 of Set 11 | Maseru
# Processing Record 18 of Set 11 | Wanning
# Processing Record 19 of Set 11 | Xique Xique
# Processing Record 20 of Set 11 | Bomdila
# Processing Record 21 of Set 11 | Tezu
# Processing Record 22 of Set 11 | Axim
# Processing Record 23 of Set 11 | Mount Pearl
# Processing Record 24 of Set 11 | Severo-Yeniseyskiy
# Processing Record 25 of Set 11 | Wusong
# Processing Record 26 of Set 11 | Siwa Oasis
# Processing Record 27 of Set 11 | Kigoma
# Processing Record 28 of Set 11 | King'S Lynn
# Processing Record 29 of Set 11 | Nowy Targ
# Processing Record 30 of Set 11 | San Luis
# Processing Record 31 of Set 11 | Guerrero Negro
# Processing Record 32 of Set 11 | Sanming
# Processing Record 33 of Set 11 | Pekan
# Processing Record 34 of Set 11 | San Juan De Miraflores
# Processing Record 35 of Set 11 | Cabedelo
# Processing Record 36 of Set 11 | Isangel
# Processing Record 37 of Set 11 | Khandyga
# Processing Record 38 of Set 11 | Sidareja
# Processing Record 39 of Set 11 | Sao Paulo De Olivenca
# Processing Record 40 of Set 11 | Hotan
# Processing Record 41 of Set 11 | Aldama
# Processing Record 42 of Set 11 | Erbach
# Processing Record 43 of Set 11 | Hun
# Processing Record 44 of Set 11 | Kibre Mengist
# Processing Record 45 of Set 11 | Mormugao
# Processing Record 46 of Set 11 | Howard Springs
# Processing Record 47 of Set 11 | Lincoln City
# Processing Record 0 of Set 12 | Ouesso
# Processing Record 1 of Set 12 | Quesnel
# Processing Record 2 of Set 12 | Vernon
# Processing Record 3 of Set 12 | Kodinsk
# Processing Record 4 of Set 12 | Okhotsk
# Processing Record 5 of Set 12 | Mantua
# Processing Record 6 of Set 12 | Olinda
# Processing Record 7 of Set 12 | Sikka
# We not found. Skipping...
# Processing Record 8 of Set 12 | Houlton
# Processing Record 9 of Set 12 | Antigonish
# Nyurba not found. Skipping...
# Processing Record 10 of Set 12 | Twon-Brass
# Processing Record 11 of Set 12 | Jiazi
# Processing Record 12 of Set 12 | Canutama
# Processing Record 13 of Set 12 | Dawei
# Processing Record 14 of Set 12 | Wilhelmsburg
# Processing Record 15 of Set 12 | Kozhevnikovo
# Processing Record 16 of Set 12 | Nadym
# Processing Record 17 of Set 12 | Jiayuguan
# Hihifo not found. Skipping...
# Processing Record 18 of Set 12 | Tadjourah
# Processing Record 19 of Set 12 | Orenburg
# Processing Record 20 of Set 12 | Livno
# Processing Record 21 of Set 12 | Igrim
# Processing Record 22 of Set 12 | Mingora
# Yamba not found. Skipping...
# Processing Record 23 of Set 12 | Levuka
# Processing Record 24 of Set 12 | Evesham
# Processing Record 25 of Set 12 | Oumache
# Processing Record 26 of Set 12 | Jinghong
# Processing Record 27 of Set 12 | Porto Murtinho
# Processing Record 28 of Set 12 | Lai Chau
# Processing Record 29 of Set 12 | Bununu
# Processing Record 30 of Set 12 | Teluknaga
# Processing Record 31 of Set 12 | Ponta Delgada
# Processing Record 32 of Set 12 | Ouro Sogui
# Processing Record 33 of Set 12 | Dutsen Wai
# Processing Record 34 of Set 12 | Farah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 567

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data) 
city_data_df

# Show Record Count
city_data_df.count()
# Out:
# City          567
# Lat           567
# Lng           567
# Max Temp      567
# Humidity      567
# Cloudiness    567
# Wind Speed    567
# Country       567
# Date          567
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         nuuk  64.1835  -51.7216      9.34        76          40        4.63
# 1   isafjordur  66.0755  -23.1240     11.02        62           0        0.51
# 2  east london -33.0153   27.9116     18.86        70           4        2.13
# 3   bredasdorp -34.5322   20.0403     12.35        90         100        5.41
# 4    adamstown -25.0660 -130.1015     18.65        73         100        7.81
#
#   Country        Date
# 0      GL  1724701804
# 1      IS  1724701806
# 2      ZA  1724701219
# 3      ZA  1724701809
# 4      PN  1724701810

# %%
# Reformat date
city_data_df['Date'] = pd.to_datetime(city_data_df['Date'], unit='s')

# Create date var for later use
date = city_data_df.loc[0, 'Date'].date().strftime('%Y-%m-%d')

# %%
# Export the City_Data into a csv
city_data_df.to_csv('output_data/cities.csv', index_label='City_ID')

# %%
# Read saved data
city_data_df = pd.read_csv('output_data/cities.csv', index_col='City_ID')

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               nuuk  64.1835  -51.7216      9.34        76          40
# 1         isafjordur  66.0755  -23.1240     11.02        62           0
# 2        east london -33.0153   27.9116     18.86        70           4
# 3         bredasdorp -34.5322   20.0403     12.35        90         100
# 4          adamstown -25.0660 -130.1015     18.65        73         100
#
#          Wind Speed Country                 Date
# City_ID
# 0              4.63      GL  2024-08-26 19:50:04
# 1              0.51      IS  2024-08-26 19:50:06
# 2              2.13      ZA  2024-08-26 19:40:19
# 3              5.41      ZA  2024-08-26 19:50:09
# 4              7.81      PN  2024-08-26 19:50:10

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat = city_data_df['Lat']
max_temp = city_data_df['Max Temp']
plt.scatter(lat, max_temp, edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title(f'City Latitude vs. Temperature ({date})')
plt.grid(True)

# Save the figure
plt.savefig('output_data/Fig1.png')

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
humidity = city_data_df['Humidity']
plt.scatter(lat, humidity, edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs. Humidity ({date})')
plt.grid(True)

# Save the figure
plt.savefig('output_data/Fig2.png')

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
cloud = city_data_df['Cloudiness']
plt.scatter(lat, cloud, edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs. Cloudiness ({date})')
plt.grid(True)

# Save the figure
plt.savefig('output_data/Fig3.png')

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
wind = city_data_df['Wind Speed']
plt.scatter(lat, wind, edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title(f'City Latitude vs. Wind Speed ({date})')
plt.grid(True)

# Save the figure
plt.savefig('output_data/Fig4.png')

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linreg_plot(x_values, y_values):
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values[1], y_values[1])
    regress_values = x_values[1] * slope + intercept
    line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

    x_quantile = np.percentile(x_values[1], [1])
    if slope > 0:
        y_quantile = np.percentile(y_values[1], [99])
    else:    
        y_quantile = np.percentile(y_values[1], [1])
        
    print(f'The r^2-value is: {rvalue**2}')

    plt.scatter(x_values[1],y_values[1], color='#a345f5', marker = '+')
    plt.plot(x_values[1],regress_values,color='#ff8800')
    plt.annotate(line_eq,(x_quantile, y_quantile),fontsize=18,color='black',weight='bold')
    plt.title(f'{x_values[0]} vs {y_values[0]}')
    plt.xlabel(x_values[0])
    plt.ylabel(y_values[0])
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0), :]

# Display sample data
northern_hemi_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 nuuk  64.1835  -51.7216      9.34        76          40
# 1           isafjordur  66.0755  -23.1240     11.02        62           0
# 5             kingston  17.9970  -76.7936     33.53        62          20
# 6               nemuro  43.3236  145.5750     18.67       100         100
# 7              susuman  62.7833  148.1667     11.76        94         100
# ...                ...      ...       ...       ...       ...         ...
# 561             bununu   9.8681    9.6628     21.69        89          92
# 563      ponta delgada  37.7333  -25.6667     25.40        78          40
# 564         ouro sogui  15.6000  -13.3167     31.82        59         100
# 565         dutsen wai  10.8501    8.1990     20.07        98          98
# 566              farah  32.5000   62.5000     28.26        14           0
#
#          Wind Speed Country                 Date
# City_ID
# 0              4.63      GL  2024-08-26 19:50:04
# 1              0.51      IS  2024-08-26 19:50:06
# 5              9.77      JM  2024-08-26 19:50:11
# 6              5.71      JP  2024-08-26 19:43:40
# 7              0.68      RU  2024-08-26 19:47:30
# ...             ...     ...                  ...
# 561            0.74      NG  2024-08-26 20:07:33
# 563            4.63      PT  2024-08-26 20:07:35
# 564            6.10      SN  2024-08-26 20:07:37
# 565            2.36      NG  2024-08-26 20:07:38
# 566            2.60      AF  2024-08-26 20:07:40
#
# [393 rows x 9 columns]

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0), :]

# Display sample data
southern_hemi_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           east london -33.0153   27.9116     18.86        70           4
# 3            bredasdorp -34.5322   20.0403     12.35        90         100
# 4             adamstown -25.0660 -130.1015     18.65        73         100
# 8              mata-utu -13.2816 -176.1745     25.82        76         100
# 13            grytviken -54.2811  -36.5092      1.76        83          64
# ...                 ...      ...       ...       ...       ...         ...
# 530      howard springs -12.4970  131.0470     22.95        94          19
# 538              olinda  -8.0089  -34.8553     26.85        65          40
# 544            canutama  -6.5339  -64.3831     36.31        24           2
# 559      porto murtinho -21.6989  -57.8825     25.20        11           0
# 562           teluknaga  -6.0989  106.6381     28.13        83          20
#
#          Wind Speed Country                 Date
# City_ID
# 2              2.13      ZA  2024-08-26 19:40:19
# 3              5.41      ZA  2024-08-26 19:50:09
# 4              7.81      PN  2024-08-26 19:50:10
# 8              4.85      WF  2024-08-26 19:49:34
# 13             3.62      GS  2024-08-26 19:50:24
# ...             ...     ...                  ...
# 530            2.06      AU  2024-08-26 20:03:02
# 538            7.20      BR  2024-08-26 20:00:05
# 544            1.43      BR  2024-08-26 20:07:05
# 559            2.97      BR  2024-08-26 20:05:53
# 562            2.06      ID  2024-08-26 20:07:34
#
# [174 rows x 9 columns]

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
north_lat = ['Latitude', northern_hemi_df['Lat']]
north_temp = ['Max Temp', northern_hemi_df['Max Temp']]
linreg_plot(north_lat, north_temp)
# Out:
# The r^2-value is: 0.4767277950845632

# %%
# Linear regression on Southern Hemisphere
south_lat = ['Latitude', southern_hemi_df['Lat']]
south_temp = ['Max Temp', southern_hemi_df['Max Temp']]
linreg_plot(south_lat, south_temp)
# Out:
# The r^2-value is: 0.6452485124884105

# %% [markdown]
# **Discussion about the linear relationship:** Here we are modelling the relationship between latitude and high temperatures in the northern and southern hemispheres. As the latitude's magnitude increases, the further away from the equator the latitude line is. As the magnitude of the latitude increases, the temperature decreases; this is to be expected since the weather at the equator is generally the hottest while the weather at the north and south poles are arctic. The r<sup>2</sup> values for the northern and southern hemispheres are .48 and .65, respectively. This tells us that about 48% of the temperature variance in the northern hemisphere can be explained by the latitude, and 65% of the temperature variance in the southern hemisphere is explained by the latitude. Other factors that may influence temperature could be elevation and the distance from large bodies of water.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
north_hum = ['Humidity', northern_hemi_df['Humidity']]
linreg_plot(north_lat, north_hum)
# Out:
# The r^2-value is: 8.693935688814542e-05

# %%
# Southern Hemisphere
south_hum = ['Humidity', southern_hemi_df['Humidity']]
linreg_plot(south_lat, south_hum)
# Out:
# The r^2-value is: 0.0001684660176166379

# %% [markdown]
# **Discussion about the linear relationship:** These scatter plots show the relationship between latitude and humidity for the northern and southern hemispheres. The linear relationship between latitude and humidity appears to be very weak. This is evidenced by r<sup>2</sup> values of .00009 and .0001 for the northern hemisphere and southern hempisheres, respectively. This means that <1% of the variance in humidity can be explained by latitude. The expected outcome was a moderately strong correlation between the two variables. Other variables that be more influencial on the humidity could be water temperature, and air movement.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
north_cloud = ['Cloudiness', northern_hemi_df['Cloudiness']]
linreg_plot(north_lat, north_cloud)
# Out:
# The r^2-value is: 0.013003320895887552

# %%
# Southern Hemisphere
south_cloud = ['Cloudiness', southern_hemi_df['Cloudiness']]
linreg_plot(south_lat, south_cloud)
# Out:
# The r^2-value is: 0.006105024621358322

# %% [markdown]
# **Discussion about the linear relationship:** These linear regression plots show the relationship between cloudiness and latitude in the northern and southern hemispheres. Latitude clearly has little to no affect on cloudiness. Both the northern and southern hemispheres have low r<sup>2</sup> values which are .01 and .006, respectively. This indicates that the variability in cloudiness must be better explained by its relationship to another variable. A better indicator of cloudiness could be humidity or wind currents.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
north_wind = ['Wind Speed', northern_hemi_df['Wind Speed']]
linreg_plot(north_lat, north_wind)
# Out:
# The r^2-value is: 0.0019239386354641813

# %%
# Southern Hemisphere
south_wind = ['Wind Speed', southern_hemi_df['Wind Speed']]
linreg_plot(south_lat, south_wind)
# Out:
# The r^2-value is: 0.0368129556941159

# %% [markdown]
# **Discussion about the linear relationship:** These linear regression plots show the relationship between latitude and wind speed in the northern and southern hemispheres. The r<sup>2</sup> values for the northern and southern hemispheres are .002 and .04, respectively. This indicates that only .02% of the variation in wind speed can be explained by latitude in the northern hemisphere and 4% of the variation in wind speed can be explained by latitude in the southern hemisphere. Other variables that may better explain this variation could be air pressure, or other variables that have not been recorded in this project.
